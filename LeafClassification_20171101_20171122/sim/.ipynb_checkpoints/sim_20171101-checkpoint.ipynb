# %% [markdown]
# # 1. variable & data 확인

# %%
import pandas as pd

# %%
pd.options.display.max_columns = 1000

# %%
train_df = pd.read_csv("/home/eigensim/[eigenSim]/FastCampus_DataScienceSchool/TeamProject_Classification/leaf/train.csv")

# %%
train_df.shape
# Out:
# (990, 194)

# %%
train_df.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8   margin9  margin10  margin11  \
# 0  0.011719  0.009766  0.027344      0.0  0.001953  0.033203  0.013672
# 1  0.025391  0.001953  0.019531      0.0  0.000000  0.007812  0.003906
# 2  0.003906  0.005859  0.068359      0.0  0.000000  0.044922  0.007812
# 3  0.021484  0.019531  0.023438      0.0  0.013672  0.017578  0.001953
# 4  0.013672  0.015625  0.005859      0.0  0.000000  0.005859  0.001953
#
#    margin12  margin13  margin14  margin15  margin16  margin17  margin18  \
# ...

# %%
train_df.tail()
# Out:
#        id               species   margin1   margin2   margin3   margin4  \
# 985  1575  Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906
# 986  1578           Acer_Pictum  0.001953  0.003906  0.021484  0.107420
# 987  1581    Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484
# 988  1582         Quercus_Rubra  0.000000  0.000000  0.046875  0.056641
# 989  1584        Quercus_Afares  0.023438  0.019531  0.031250  0.015625
#
#       margin5   margin6   margin7  margin8   margin9  margin10  margin11  \
# 985  0.000000  0.148440  0.017578      0.0  0.001953  0.042969  0.041016
# 986  0.001953  0.000000  0.000000      0.0  0.029297  0.003906  0.023438
# 987  0.078125  0.003906  0.007812      0.0  0.003906  0.000000  0.000000
# 988  0.009766  0.000000  0.000000      0.0  0.037109  0.001953  0.000000
# 989  0.005859  0.019531  0.035156      0.0  0.003906  0.039062  0.025391
#
#      margin12  margin13  margin14  margin15  margin16  margin17  margin18  \
# ...

# %%
test_df = pd.read_csv("/home/eigensim/[eigenSim]/FastCampus_DataScienceSchool/TeamProject_Classification/leaf/test.csv")

# %%
test_df.shape
#species 없음
# Out:
# (594, 193)

# %%
test_df.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  margin10  margin11  margin12  margin13  margin14  \
# 0      0.0  0.005859  0.023438  0.005859  0.021484  0.076172  0.001953
# 1      0.0  0.033203  0.023438  0.009766  0.019531  0.039062  0.027344
# 2      0.0  0.011719  0.005859  0.001953  0.021484  0.001953  0.019531
# 3      0.0  0.003906  0.001953  0.000000  0.029297  0.000000  0.039062
# 4      0.0  0.005859  0.000000  0.001953  0.033203  0.000000  0.003906
#
#    margin15  margin16  margin17  margin18  margin19  margin20  margin21  \
# ...

# %%
test_df.tail()
# Out:
#        id   margin1   margin2   margin3   margin4   margin5   margin6  \
# 589  1576  0.000000  0.000000  0.003906  0.015625  0.041016  0.000000
# 590  1577  0.000000  0.003906  0.003906  0.005859  0.017578  0.000000
# 591  1579  0.017578  0.029297  0.015625  0.013672  0.003906  0.015625
# 592  1580  0.013672  0.009766  0.060547  0.025391  0.035156  0.025391
# 593  1583  0.000000  0.117190  0.000000  0.019531  0.000000  0.136720
#
#       margin7   margin8   margin9  margin10  margin11  margin12  margin13  \
# 589  0.017578  0.000000  0.005859  0.013672  0.003906  0.013672  0.000000
# 590  0.017578  0.005859  0.000000  0.005859  0.001953  0.033203  0.003906
# 591  0.025391  0.000000  0.000000  0.009766  0.005859  0.017578  0.056641
# 592  0.039062  0.000000  0.003906  0.023438  0.003906  0.003906  0.025391
# 593  0.001953  0.005859  0.000000  0.007812  0.068359  0.000000  0.154300
#
#      margin14  margin15  margin16  margin17  margin18  margin19  margin20  \
# ...

# %%
sample_submission_df = pd.read_csv("/home/eigensim/[eigenSim]/FastCampus_DataScienceSchool/TeamProject_Classification/leaf/sample_submission.csv")

# %%
sample_submission_df.shape
# Out:
# (594, 100)

# %%
sample_submission_df.head()
# Out:
#    id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 0   4         0.010101         0.010101   0.010101     0.010101
# 1   7         0.010101         0.010101   0.010101     0.010101
# 2   9         0.010101         0.010101   0.010101     0.010101
# 3  12         0.010101         0.010101   0.010101     0.010101
# 4  13         0.010101         0.010101   0.010101     0.010101
#
#    Acer_Palmatum  Acer_Pictum  Acer_Platanoids  Acer_Rubrum  Acer_Rufinerve  \
# 0       0.010101     0.010101         0.010101     0.010101        0.010101
# 1       0.010101     0.010101         0.010101     0.010101        0.010101
# 2       0.010101     0.010101         0.010101     0.010101        0.010101
# 3       0.010101     0.010101         0.010101     0.010101        0.010101
# 4       0.010101     0.010101         0.010101     0.010101        0.010101
#
#    Acer_Saccharinum  Alnus_Cordata  Alnus_Maximowiczii  Alnus_Rubra  \
# ...

# %%
sample_submission_df.tail()
# Out:
#        id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 589  1576         0.010101         0.010101   0.010101     0.010101
# 590  1577         0.010101         0.010101   0.010101     0.010101
# 591  1579         0.010101         0.010101   0.010101     0.010101
# 592  1580         0.010101         0.010101   0.010101     0.010101
# 593  1583         0.010101         0.010101   0.010101     0.010101
#
#      Acer_Palmatum  Acer_Pictum  Acer_Platanoids  Acer_Rubrum  Acer_Rufinerve  \
# 589       0.010101     0.010101         0.010101     0.010101        0.010101
# 590       0.010101     0.010101         0.010101     0.010101        0.010101
# 591       0.010101     0.010101         0.010101     0.010101        0.010101
# 592       0.010101     0.010101         0.010101     0.010101        0.010101
# 593       0.010101     0.010101         0.010101     0.010101        0.010101
#
#      Acer_Saccharinum  Alnus_Cordata  Alnus_Maximowiczii  Alnus_Rubra  \
# ...

# %% [markdown]
# - csv 필수 제출 내용 = id, 분류 명칭, 각 id가 각 분류 명칭이 될 확률
# - 행의 순서는 상관 없음

# %%
("/home/eigensim/[eigenSim]/FastCampus_DataScienceSchool/TeamProject_Classification/leaf/images/1.jpg")
